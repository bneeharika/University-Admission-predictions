# %%
import pandas as pd
import numpy as np

# %%
grad=pd.read_csv('Admission_Predict_Ver1.1.csv')
grad.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research   COA
# 0         1  0.92
# 1         1  0.76
# 2         1  0.72
# 3         1  0.80
# 4         0  0.65

# %%
grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
# Serial No.           500 non-null int64
# GRE Score            500 non-null int64
# TOEFL Score          500 non-null int64
# University Rating    500 non-null int64
# SOP                  500 non-null float64
# LOR                  500 non-null float64
# CGPA                 500 non-null float64
# Research             500 non-null int64
# COA                  500 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 35.2 KB

# %%
from sklearn.model_selection import train_test_split

# %%
y=grad['COA']
y.head(5)
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: COA, dtype: float64

# %%
X=grad.drop('COA',axis=1)
X.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y,test_size=0.20)
X_train
y_train
# Out:
# 4      0.65
# 11     0.84
# 443    0.87
# 460    0.77
# 358    0.70
# 33     0.90
# 118    0.47
# 498    0.73
# 196    0.73
# 186    0.84
# 330    0.80
# 300    0.62
# 201    0.72
# 377    0.47
# 145    0.81
# 137    0.71
# 429    0.95
# 150    0.93
# 367    0.57
# 104    0.74
# 161    0.53
# 182    0.68
# 380    0.78
# 343    0.59
# 243    0.76
# 351    0.73
# 26     0.76
# 481    0.78
# 456    0.51
# 315    0.65
#        ...
# 159    0.52
# 411    0.56
# 373    0.79
# 185    0.89
# 135    0.82
# 454    0.71
# 392    0.84
# 447    0.84
# 152    0.86
# 399    0.95
# 473    0.67
# 287    0.89
# 27     0.44
# 83     0.92
# 63     0.56
# 295    0.68
# 51     0.56
# 386    0.46
# 92     0.34
# 212    0.95
# 47     0.89
# 452    0.93
# 279    0.67
# 356    0.79
# 241    0.65
# 13     0.62
# 84     0.94
# 199    0.72
# 262    0.70
# 236    0.85
# Name: COA, Length: 400, dtype: float64

# %%
X_train
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 4             5        314          103                  2  2.0   3.0  8.21
# 11           12        327          111                  4  4.0   4.5  9.00
# 443         444        321          114                  5  4.5   4.5  9.16
# 460         461        319          105                  4  4.0   4.5  8.66
# 358         359        314          105                  2  2.5   2.0  7.64
# 33           34        340          114                  5  4.0   4.0  9.60
# 118         119        296           99                  2  3.0   3.5  7.28
# 498         499        312          103                  4  4.0   5.0  8.43
# 196         197        306          105                  2  3.0   2.5  8.26
# 186         187        317          107                  3  3.5   3.0  8.68
# 330         331        327          113                  3  3.5   3.0  8.66
# ...

# %%
X1=grad['GRE Score']

# %%
X1_train, X1_test, y1_train, y2_test=train_test_split(X1, y,test_size=0.20)
X1_train
# Out:
# 284    340
# 422    322
# 85     319
# 321    323
# 469    326
# 104    326
# 281    317
# 135    314
# 161    298
# 188    331
# 50     313
# 352    303
# 0      337
# 307    325
# 16     317
# 236    325
# 137    316
# 147    326
# 277    320
# 251    316
# 258    326
# 202    340
# 139    318
# 361    334
# 318    324
# 310    320
# 63     315
# 324    315
# 240    296
# 463    304
#       ...
# 116    299
# 265    313
# 112    301
# 408    297
# 223    308
# 296    310
# 122    310
# 132    309
# 79     294
# 102    314
# 434    306
# 10     325
# 2      316
# 208    305
# 354    297
# 261    312
# 160    315
# 444    324
# 193    336
# 106    329
# 90     318
# 145    320
# 158    306
# 192    322
# 382    324
# 180    300
# 413    317
# 450    320
# 3      322
# 110    305
# Name: GRE Score, Length: 400, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
grad.plot(kind='scatter', x='GRE Score', y='COA',title="GRE VS COA")
plt.plot([300, 340],[0.4, 1], color='red', linewidth=2)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
def curv_mse(true,pred):
  s=(pred-true)**2
  return s.mean()

def model(ip, w, b):
  return (ip*w)+b

# %%
pred=model(X1,1,2)

curv_mse(grad['COA'], pred)
# Out:
# 101089.99426940002

# %%
op=pd.DataFrame()

# %%
mses=[]
for i in np.arange(1,2,0.2):
  for b in np.arange(0.2,0.6,0.1):
    y_pred=model(X1,i,b)
    mse=curv_mse(y,y_pred)
    op=pd.concat([op,pd.DataFrame({'w':[i],'b':[b],'error':[mse]})])

# %%
print(op)
# Out:
#      b          error    w
# 0  0.2   99949.333333  1.0
# 0  0.3  100012.533385  1.0
# 0  0.4  100075.753437  1.0
# 0  0.5  100138.993489  1.0
# 0  0.2  144006.786061  1.2
# 0  0.3  144082.644993  1.2
# 0  0.4  144158.523925  1.2
# 0  0.5  144234.422857  1.2
# 0  0.2  196086.786949  1.4
# 0  0.3  196175.304761  1.4
# 0  0.4  196263.842573  1.4
# 0  0.5  196352.400385  1.4
# 0  0.2  256189.335997  1.6
# 0  0.3  256290.512689  1.6
# 0  0.4  256391.709381  1.6
# 0  0.5  256492.926073  1.6
# 0  0.2  324314.433205  1.8
# 0  0.3  324428.268777  1.8
# 0  0.4  324542.124349  1.8
# 0  0.5  324655.999921  1.8

# %%
plt.figure(figsize=(10,5))
ax1=plt.subplot(121)
grad.plot(kind='scatter',x='GRE Score', y='COA',title='GRE VS COA',ax=ax1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
